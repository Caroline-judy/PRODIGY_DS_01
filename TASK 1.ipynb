# %% [markdown]
# # TASK 1
# Create a bar chart or histogram tO visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %%
import pandas as pd
import zipfile

# Unzipping the provided dataset
with zipfile.ZipFile('Data Files.zip', 'r') as zip_ref:
    zip_ref.extractall('data_files')

# Listing the extracted files to understand what we have
import os
extracted_files = os.listdir('data_files')
extracted_files
# Out:
# ['API_SP.POP.TOTL_DS2_en_csv_v2_144171.csv',
#  'Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_144171.csv',
#  'Metadata_Indicator_API_SP.POP.TOTL_DS2_en_csv_v2_144171.csv']

# %%
import pandas as pd

# Load the datasets
pop_data = pd.read_csv('data_files/API_SP.POP.TOTL_DS2_en_csv_v2_144171.csv', skiprows=4)
metadata_indicator = pd.read_csv('data_files/Metadata_Indicator_API_SP.POP.TOTL_DS2_en_csv_v2_144171.csv')
metadata_country = pd.read_csv('data_files/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_144171.csv')

# Display the first few rows of each dataset
print('Population Data:')
print(pop_data.head())
print('\
Metadata Indicator:')
print(metadata_indicator.head())
print('\
Metadata Country:')
print(metadata_country.head())
# Out:
# Population Data:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Extract population data for the year 2020
pop_2020 = pop_data[['Country Name', '2020']].dropna()
pop_2020.columns = ['Country', 'Population_2020']

# Plotting the distribution of population in 2020
plt.figure(figsize=(12, 6))
sns.histplot(pop_2020['Population_2020'], bins=30, kde=True)
plt.title('Distribution of Population in 2020')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.show()
# Out:
# c:\Users\carol\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Histogram of Population Data for 2020:
#
# • The histogram shows that the majority of countries have populations below 50 million.
#
# • There are a few countries with very high populations, creating a long tail on the right
# side of the distribution.

# %%
# Extract the income group data
income_group_data = metadata_country[['Country Code', 'IncomeGroup']].dropna()

# Count the number of countries in each income group
income_group_counts = income_group_data['IncomeGroup'].value_counts()

# Plotting the distribution of income groups
plt.figure(figsize=(12, 6))
sns.barplot(x=income_group_counts.index, y=income_group_counts.values)
plt.title('Distribution of Income Groups')
plt.xlabel('Income Group')
plt.ylabel('Number of Countries')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This bar chart shows the number of countries in each income group.

# %%
# Extract the region data
region_data = metadata_country[['Country Code', 'Region']].dropna()

# Count the number of countries in each region
region_counts = region_data['Region'].value_counts()

# Plotting the distribution of regions
plt.figure(figsize=(12, 6))
sns.barplot(x=region_counts.index, y=region_counts.values)
plt.title('Distribution of Regions Among Countries')
plt.xlabel('Region')
plt.ylabel('Number of Countries')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate the population growth rate
df = india_pop.copy()
df['Population Growth Rate'] = df['Population'].pct_change() * 100

# Plotting the population growth rate over the years
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='Population Growth Rate')
plt.title('Population Growth Rate of India Over the Years')
plt.xlabel('Year')
plt.ylabel('Population Growth Rate (%)')
plt.show()
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_8216\4196808151.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Population Growth Rate'] = df['Population'].pct_change() * 100
# c:\Users\carol\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\carol\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %% [markdown]
# # Population Growth Rate:
#
# • The population growth rate shows the percentage change in population year over year.
#
# •There are noticeable fluctuations in the growth rate, with some years experiencing higher growth rates than others.
#
# •This can help identify periods of rapid population growth or decline.

# %%
# Calculate the population distribution by decades
df['Decade'] = (df['Year'] // 10) * 10
decade_population = df.groupby('Decade')['Population'].mean().reset_index()

# Plotting the population distribution by decades
plt.figure(figsize=(12, 6))
sns.barplot(data=decade_population, x='Decade', y='Population')
plt.title('Average Population of India by Decades')
plt.xlabel('Decade')
plt.ylabel('Average Population')
plt.show()

# %% [markdown]
# # Average Population by Decades:
#
# • This bar plot shows the average population of India for each decade.
# It provides a clear view of how the population has increased over each decade.
#
# • The population has been steadily increasing, with significant growth observed in recent decades.
